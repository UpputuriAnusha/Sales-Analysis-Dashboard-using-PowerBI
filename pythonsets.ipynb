# %% [markdown]
# <a href="https://colab.research.google.com/github/UpputuriAnusha/Data-Analysis-Dashboard/blob/main/pythonsets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#crate and print set
s={5,10,15,20}
print(s)
# Out:
# {10, 20, 5, 15}

# %%
#add element to set
s={5,10,15,20}
s.add(20)
print(s)
# Out:
# {10, 20, 5, 15}

# %%
#updating the set with multiple elements
s={5,10,15,20}
s.update([25,36])
print(s)
# Out:
# {36, 5, 10, 15, 20, 25}

# %%
#remove an element in the set
s={5,10,15,20}
s.discard(10)
s.discard(22) # Using discard() instead of remove()
print(s)
# Out:
# {20, 5, 15}

# %%
#discarding the set
s={5,10,15,20}
s.discard(22)
s.discard(5)
print(s)
# Out:
# {10, 20, 15}

# %%
#set union
s={5,10,15,20}
u={2,4,6,8}
print(s|u)
# Out:
# {2, 4, 5, 6, 8, 10, 15, 20}

# %%
#set intersection
s={5,10,15,20}
u={2,4,5,20}
print(s&u)
# Out:
# {20, 5}

# %%
#check is subset or superset
a={10}
b={10,20,30}
print(a.issubset(b))
print(b.issuperset(a))
# Out:
# True
# True

# %%
#removing all elements from a set
s={5,10,15,20}
s.clear()
print(s)
# Out:
# set()
